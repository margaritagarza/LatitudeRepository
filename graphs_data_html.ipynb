# %%
import pandas as pd
import matplotlib.pyplot as plt
import time
from datetime import date

# %%
data_df = pd.read_csv('Homework HTML_CSS_cities.csv')

# %%
data_df.to_html('table.html', index=False)

# %%
data_df
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0  jacareacanga           0      BR  1528902000        62  -6.22
# 1          1    kaitangata         100      NZ  1528905304        94 -46.28
# 2          2      goulburn          20      AU  1528905078        91 -34.75
# 3          3          lata          76      IN  1528905305        89  30.78
# 4          4    chokurdakh           0      RU  1528905306        88  70.62
# ..       ...           ...         ...     ...         ...       ...    ...
# 542      542        scalea          36      IT  1528905631       100  39.82
# 543      543    san andres          68      PH  1528905632       100  13.32
# 544      544        muisne          92      EC  1528905633        84   0.61
# 545      545           ati          20      TD  1528905633        25  13.21
# 546      546      san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
today = date.today()
print(f"Today's date: {today}")
# Out:
# Today's date: 2020-08-16

# %%
plt.scatter(data_df['Lat'],data_df['Max Temp'],marker='o',edgecolors="black")
plt.xlabel('Latitude')
plt.ylabel('Max Temprerature (F)')
plt.title(f"Latitude vs. Max Temperature:{today}")
plt.savefig('LatvsMaxTemp.png')
plt.grid()
plt.show()

# %%
plt.scatter(data_df['Lat'],data_df['Humidity'],marker='o',edgecolors="black")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f"Latitude vs. Humidity Plot Date:{today}")
plt.tight_layout()
plt.savefig('LatvsHumidity.png')
plt.grid()
plt.show()

# %%
plt.scatter(data_df['Lat'],data_df['Cloudiness'],marker='o',edgecolors="black")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f"Latitude vs. Cloudiness Plot Date:{today}")
plt.savefig('LatitudevsCloudiness.png')
plt.grid()
plt.show()

# %%
plt.scatter(data_df['Lat'],data_df['Wind Speed'],marker='o',edgecolors="black")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f"Latitude vs. Wind Speed Plot Date:{today}")
plt.savefig('Latitude vs. Wind Speed Scatter Plot.png')
plt.grid()
plt.show()
